# %% [markdown]
# # ETL

# %%
import pandas as pd
pd.options.display.max_rows = 7000
pd.options.display.max_colwidth = 250
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Test Dataset

# %%
df = pd.read_excel("../data/COVID19_Twitter_Dataset.xlsx")

# %%
df.head()
# Out:
#    Is_Unreliable    Category  \
# 0              1  1, 3, 6, 9
# 1              1  1, 6, 8, 9
# 2              1     1, 4, 9
# 3              1        6, 8
# 4              1     6, 8, 9
#
#                                                                                                                                Tweet
# 0                                        We are living in scary times in Canada. Gov’t refuses to protect Canadians from coronavirus
# 1                Just as bad in Canada. In fact, our government is now accusing us of racism for blaming the Chinese for coronavirus
# 2            It was only a matter of time before the mainstream media decided to blame the coronavirus on climate change, I suppose.
# 3  Russia's taking no chances: Foreigners infected with the new Chinese coronavirus will be quarantined, isolated &amp; deported, PM
# 4         Although there is now a presumptive confirmed case of Wuhan novel coronavirus, I want you to know that Ontario is prepared

# %%
df = df[['Tweet', 'Is_Unreliable']]
df.columns = [col.lower() for col in df.columns.to_list()]

# %%
df.columns = ['text', 'label']

# %%
df.label = df.label.map({0:'true', 1:'unreliable'})

# %%
# lower lettering and trimming spaces for all values
text_cols = df.columns.to_list()
text_cols.remove('label')
for col in text_cols:
    df[col] = df[col].str.strip().str.lower()

# %%
df.head()
# Out:
#                                                                                                                                 text  \
# 0                                        we are living in scary times in canada. gov’t refuses to protect canadians from coronavirus
# 1                just as bad in canada. in fact, our government is now accusing us of racism for blaming the chinese for coronavirus
# 2            it was only a matter of time before the mainstream media decided to blame the coronavirus on climate change, i suppose.
# 3  russia's taking no chances: foreigners infected with the new chinese coronavirus will be quarantined, isolated &amp; deported, pm
# 4         although there is now a presumptive confirmed case of wuhan novel coronavirus, i want you to know that ontario is prepared
#
#         label
# 0  unreliable
# 1  unreliable
# 2  unreliable
# 3  unreliable
# 4  unreliable

# %%
df[df.duplicated(subset=['text'], keep=False)].sort_values('text').head(30)
# Out:
#                                                                                                                          text  \
# 394        according to health officials, this is what you will need for a #coronavirus home quarantine for 14 days #covid-19
# 397        according to health officials, this is what you will need for a #coronavirus home quarantine for 14 days #covid-19
# 395                       coronavirus: how does it spread and what are the symptoms? here’s everything we know about covid-19
# 557                       coronavirus: how does it spread and what are the symptoms? here’s everything we know about covid-19
# 307  don't fall victim to misinformation and even worst fake news. get the facts about the #coronavirus from @topublichealth.
# 489  don't fall victim to misinformation and even worst fake news. get the facts about the #coronavirus from @topublichealth.
#
#     label
# 394  true
# 397  true
# 395  true
# 557  true
# 307  true
# 489  true

# %%
print('before dropping duplicates', len(df))
df = df.drop_duplicates(keep='first')
print('after', len(df))
# Out:
# before dropping duplicates 560
# after 557

# %% [markdown]
# ## Cleaning Text

# %%
# removing links
reg_url = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
df['cleaned'] = df.text.str.replace(reg_url, ' ', regex=True)

# %%
reg_mention = r'@\w+'
df.cleaned = df.cleaned.str.replace(reg_mention, ' ', regex=True)

# %%
reg_rt = r'\s+RT\s+'
df.cleaned = df.cleaned.str.replace(reg_rt, ' ', regex=True)

# %%
# change 5g so it doesn't get removed with alphabetic exception
reg_5g = r'5g'
df.cleaned = df.cleaned.str.replace(reg_5g, 'fiveg', regex=True)

# %%
# remove all non alphabetic characters
reg_non_alpha = r'[^a-z]'
df.cleaned = df.cleaned.str.replace(reg_non_alpha, ' ', regex=True)

# %%
# replace back fiveg to 5g
reg_fiveg = r'fiveg'
df.cleaned = df.cleaned.str.replace(reg_fiveg, '5g', regex=True)

# %%
reg_spaces = r'\\s{2,}'
# applying regex to remove links, non-alphas, and 2 or more spaces
df.cleaned = df.cleaned.str.replace(reg_spaces, '', regex=True)

# %%
# trimming leading and trailing spaces again since regex replacement creates some unwanted spaces
df.cleaned = df.cleaned.str.strip()

# %%
# removing stop words
df.cleaned = df.cleaned.apply(lambda x: ' '.join([word for word in x.split() if word not in stopwords.words('english')]))

# %%
# lemmatization only
lemmatizer = WordNetLemmatizer()

# preview
lemmatizer.lemmatize(df.cleaned[0])
# Out:
# 'living scary times canada gov refuses protect canadians coronavirus'

# %%
df.cleaned = df.cleaned.apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# %%
# replacing back the word u to us since lemmatization makes a mistake on US
df.cleaned = df.cleaned.str.replace(r'\su\s', ' us ', regex=True)

# %%
df.head(50)
# Out:
#                                                                                                                                                                                                                                                          text  \
# 0                                                                                                                                                                 we are living in scary times in canada. gov’t refuses to protect canadians from coronavirus
# 1                                                                                                                                         just as bad in canada. in fact, our government is now accusing us of racism for blaming the chinese for coronavirus
# 2                                                                                                                                     it was only a matter of time before the mainstream media decided to blame the coronavirus on climate change, i suppose.
# 3                                                                                                                           russia's taking no chances: foreigners infected with the new chinese coronavirus will be quarantined, isolated &amp; deported, pm
# 4                                                                                                                                  although there is now a presumptive confirmed case of wuhan novel coronavirus, i want you to know that ontario is prepared
# 5                                                                                                                                 hooray, finally there is a propaganda banner telling people they can make babies if getting bored staying home #coronavirus
# 6                                                                                                                                       #russia is pushing propaganda claiming the #coronavirus is a us bio weapon targeting #china because of #trump’s trade
# 7                                                                                        who says it's not safe to travel to china? | @nytimes https://t.co/xncdnqumwi #travelmarketing #coronavirus #china #travelwarning #travel #thursdaythoughts #toronto
# 8                                                                                                                                       the best defense against disturbing new diseases like #coronavirus is bolstering public health systems of the world’s
# 9                                       china, desperate to stop coronavirus, turns neighbor against neighbor “(people from wuhan) are pariahs in china, among the millions unable to go home and feared as potential carriers of the mysterious coronavirus.
# 10                                                                                                                                  coronavirus, with zero american fatalities, is dominating headlines, while the flu has killed dozens of u.s. kids this s…
# 11                                                                                                                             rt @daveaurkov: #iran just killed 57 of our citizens. the #coronavirus is spreading for canadians   our economy needs support.
# 12                                                                                                                                                the chinese coronavirus has become a major existential crisis for secretary xi and his cadre of miscreants.
# 13                                                                           diseases like coronavirus remind us why we need robust institutions and investments in public health, and a government that is prepared to jump into action at a moment's notice
# 14                                                                                                                                                   ya think!!?!!?! study claiming new #coronavirus can be transmitted by people without symptoms was flawed
# 15                                                                                                                     it was good for publicity’ says man arrested for false coronavirus claim on jamaica-bound plane - via @680news https://t.co/idydbxqpqq
# 16                                                                                                                                                 the #coronavirus outbreak may have been predicted in the bible, as well as its origins in china's markets.
# 17                                                                                                                                            coronavirus cure: 'substantial benefits' recorded after breakthrough drug used in china https://t.co/iyjwuttkbc
# 18                                                                                                                             i see more and more videos of people refusing to be quarantined due to #coronavirus. they’re definitely terrified of something
# 19                                                                                                                                    communist china is lying about true extent of coronavirus outbreak - if communist china doesn’t come clean, internation
# 20                                                                                                                                       exclusive: chinese regime deploys 1,600 online trolls to suppress information on coronavirus https://t.co/jkopgu6vln
# 11  unreliable
# 12  unreliable
# 13  unreliable
# 14  unreliable
# 15  unreliable
# 16  unreliable
# 17  unreliable
# 18  unreliable
# 19  unreliable
# 20  unreliable
# 21  unreliable
# 22  unreliable
# 23  unreliable
# 24  unreliable
# 25  unreliable
# 26  unreliable
# 27  unreliable
# 28  unreliable
# 29  unreliable
# 30  unreliable
# 31  unreliable
# 32  unreliable
# 33  unreliable
# 34  unreliable
# 35  unreliable
# 36  unreliable
# 37  unreliable
# 38  unreliable
# 39  unreliable
# 40  unreliable
# 41  unreliable
# 42  unreliable
# 43  unreliable
# 44  unreliable
# 45  unreliable
# 46  unreliable
# 47  unreliable
# 48  unreliable
# 49  unreliable
#
#                                                                                                                                                                 cleaned
# 0                                                                                                      living scary time canada gov refuse protect canadian coronavirus
# 1                                                                                             bad canada fact government accusing us racism blaming chinese coronavirus
# 2                                                                                        matter time mainstream medium decided blame coronavirus climate change suppose
# 3                                                                  russia taking chance foreigner infected new chinese coronavirus quarantined isolated amp deported pm
# 4                                                                                although presumptive confirmed case wuhan novel coronavirus want know ontario prepared
# 5                                                                      hooray finally propaganda banner telling people make baby getting bored staying home coronavirus
# 6                                                                              russia pushing propaganda claiming coronavirus us bio weapon targeting china trump trade
# 7                                                                 say safe travel china travelmarketing coronavirus china travelwarning travel thursdaythoughts toronto
# 8                                                                            best defense disturbing new disease like coronavirus bolstering public health system world
# 9        china desperate stop coronavirus turn neighbor neighbor people wuhan pariah china among million unable go home feared potential carrier mysterious coronavirus
# 10                                                                                       coronavirus zero american fatality dominating headline flu killed dozen us kid
# 11                                                                                           rt iran killed citizen coronavirus spreading canadian economy need support
# 12                                                                                     chinese coronavirus become major existential crisis secretary xi cadre miscreant
# 13                                    disease like coronavirus remind us need robust institution investment public health government prepared jump action moment notice
# 14                                                                                    ya think study claiming new coronavirus transmitted people without symptom flawed
# 15                                                                                      good publicity say man arrested false coronavirus claim jamaica bound plane via
# 16                                                                                                    coronavirus outbreak may predicted bible well origin china market
# 17                                                                                           coronavirus cure substantial benefit recorded breakthrough drug used china
# 18                                                                                 see video people refusing quarantined due coronavirus definitely terrified something
# 19                                                                        communist china lying true extent coronavirus outbreak communist china come clean internation
# 20                                                                                       exclusive chinese regime deploys online troll suppress information coronavirus
# 21                                                                        nose running morning making white people commute nervous bitch there coronavirus case toronto
# 22                                                                  hey american imagine coronavirus us school closed human locked inside home better prepare something
# 23                                                                                         day maga world declaring coronavirus designed noted genetic engineer hillary
# 24                                                                                          president telling people buy stock rather helping educate avoid coronavirus
# 25                                                                           agree coronavirus used fossil fuel industry auto industry air cover negative secular trend
# 26                                                                                               appears apartment building sealed shut part china hard hit coronavirus
# 27                                                                                       coronavirus prof trump correct us must rebuke globalism self sufficient aspect
# 28                                                                               coronavirus crisis make anything clear need stop relying china critical medical supply
# 29                                                                                 professor emerita us c berkeley school public health say magats prepared coronavirus
# 30                                                                               chinese city shenzhen ban eating cat dog part move stop spread coronavirus south china
# 31                                                                                                   complete dna coronavirus sars cov attacked kilobyte virus remember
# 32                                                                         usual suspect try find way blame presidenttrump coronavirus attn pathetic pelosi people kill
# 33                                                                                     going viral lysol spray known kill version human coronavirus product label lysol
# 34                                                                             cnn deliberately trying incite panic presidenttrump coronavirus plan talking point watch
# 35                                                                                                  watch trump attempt downplay coronavirus spread order help election
# 36                                                                                                  janet yellen said coronavirus could put us recession plan folk hype
# 37                                                                             please stop spreading lie coronavirus super super super contagious contagious rating two
# 38                                                                                     harvard epidemiologist predicts world population get coronavirus next year virus
# 39                                                                            best advice investor amid coronavirus scare tsx stock handing special dividend gics avoid
# 40                                                                                                  american buy drink corona beer coronavirus grasped trump presidency
# 41                                                                 china concerned western authoritarian government cover coronavirus outbreak coronavirusupdates covid
# 42                              donald trump battling coronavirus people think science fraud earth flat jesus chased dinosaur edge world make room christian trumpvirus
# 43                                                        post exclusive trump administration sent us worker greet returning coronavirus victim without protective gear
# 44                                                                                   think penny used trump coronavirus scapegoat becomes pandemic us trump blame penny
# 45                                                                                    report coronavirus case iran dead already similar china iranian government hiding
# 46                                          update chinese communist party ccp admits internal report showing coronavirus originate huanan food market initially stated
# 47  trump asserts coronavirus control stock plunge well controlled trump melania wear mask return united state confined would also help make america safer place reside
# 48                                                                                                              chinese people eating bat soup linked coronavirus video
# 49                                                                                                trump announce coronavirus task force everyone got mad many white men

# %%
df[df.duplicated(subset=['cleaned'], keep=False)].sort_values('cleaned').head(20)
# Out:
# Empty DataFrame
# Columns: [text, label, cleaned]
# Index: []

# %%
print('before dropping duplicates', len(df))
df = df.drop_duplicates(subset = ['cleaned'], keep='first')
print('after', len(df))
# Out:
# before dropping duplicates 557
# after 557

# %%
df['num_words'] = df.cleaned.str.split().apply(len)

# %%
df.head()
# Out:
#                                                                                                                                 text  \
# 0                                        we are living in scary times in canada. gov’t refuses to protect canadians from coronavirus
# 1                just as bad in canada. in fact, our government is now accusing us of racism for blaming the chinese for coronavirus
# 2            it was only a matter of time before the mainstream media decided to blame the coronavirus on climate change, i suppose.
# 3  russia's taking no chances: foreigners infected with the new chinese coronavirus will be quarantined, isolated &amp; deported, pm
# 4         although there is now a presumptive confirmed case of wuhan novel coronavirus, i want you to know that ontario is prepared
#
#         label  \
# 0  unreliable
# 1  unreliable
# 2  unreliable
# 3  unreliable
# 4  unreliable
#
#                                                                                                 cleaned  \
# 0                                      living scary time canada gov refuse protect canadian coronavirus
# 1                             bad canada fact government accusing us racism blaming chinese coronavirus
# 2                        matter time mainstream medium decided blame coronavirus climate change suppose
# 3  russia taking chance foreigner infected new chinese coronavirus quarantined isolated amp deported pm
# 4                although presumptive confirmed case wuhan novel coronavirus want know ontario prepared
#
#    num_words
# 0          9
# 1         10
# 2         10
# 3         13
# 4         11

# %%
df[df.num_words == 3]
# Out:
#                                               text       label  \
# 243                       coronavirus is fake news  unreliable
# 247  @koshtorontosun don't lie to us #coronaviruse  unreliable
# 499              how to tell if a cold is covid-19        true
#
#                    cleaned  num_words
# 243  coronavirus fake news          3
# 247    lie us coronaviruse          3
# 499        tell cold covid          3

# %%
df[df.num_words == 2]
# Out:
# Empty DataFrame
# Columns: [text, label, cleaned, num_words]
# Index: []

# %%
# removal of less than 3 words
df = df[df.num_words > 2]

# %%
df.label.value_counts(), df.label.value_counts(normalize=True)
# Out:
# (unreliable    280
#  true          277
#  Name: label, dtype: int64,
#  unreliable    0.502693
#  true          0.497307
#  Name: label, dtype: float64)

# %%
df.to_pickle('../data/cleaned_tweets_test.pkl')
