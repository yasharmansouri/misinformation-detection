# %%
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %%
training_sg = pd.read_pickle('../data/te_sg_df_training.pickle')
testing_sg = pd.read_pickle('../data/te_sg_df_testing.pickle')

# %%
training_sg = training_sg.iloc[:, 1:]
testing_sg = testing_sg.iloc[:, 1:]

# %%
exp = setup(data=training_sg, target='label', train_size=0.8)
# Out:
# <style type="text/css">
# #T_44e74_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_44e74_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44e74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44e74_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_44e74_row0_col1" class="data row0 col1" >6890</td>
#     </tr>
#     <tr>
#       <th id="T_44e74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44e74_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_44e74_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_44e74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44e74_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_b3236_ th {
#   text-align: left;
# }
# ...

# %%
exp_test = setup(data=training_sg, target='label', test_data=testing_sg)
# Out:
# <style type="text/css">
# #T_83edb_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83edb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83edb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83edb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_83edb_row0_col1" class="data row0 col1" >632</td>
#     </tr>
#     <tr>
#       <th id="T_83edb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83edb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83edb_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_83edb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83edb_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f8e7a_ th {
#   text-align: left;
# }
# ...

# %%
lgb = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_53c9a_row10_col0, #T_53c9a_row10_col1, #T_53c9a_row10_col2, #T_53c9a_row10_col3, #T_53c9a_row10_col4, #T_53c9a_row10_col5, #T_53c9a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_53c9a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53c9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53c9a_row0_col0" class="data row0 col0" >0.9719</td>
#       <td id="T_53c9a_row0_col1" class="data row0 col1" >0.9968</td>
# ...

# %%
tuned_lgb = tune_model(lgb)
# Out:
# <style type="text/css">
# #T_f8eef_row10_col0, #T_f8eef_row10_col1, #T_f8eef_row10_col2, #T_f8eef_row10_col3, #T_f8eef_row10_col4, #T_f8eef_row10_col5, #T_f8eef_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f8eef_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8eef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8eef_row0_col0" class="data row0 col0" >0.9675</td>
#       <td id="T_f8eef_row0_col1" class="data row0 col1" >0.9963</td>
# ...

# %%
plot_model(tuned_lgb, 'confusion_matrix')

# %%
# final_lgb = finalize_model(tuned_lgb)

# %%
# test_preds = predict_model(final_lgb, data = testing_sg)
