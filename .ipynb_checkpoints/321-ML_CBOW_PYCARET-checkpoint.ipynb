# %%
from datetime import datetime
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %%
training_cbow = pd.read_pickle('../data/te_cbow_df_training.pickle')
testing_cbow = pd.read_pickle('../data/te_cbow_df_testing.pickle')

# %%
training_cbow = training_cbow.iloc[:, 1:]
testing_cbow = testing_cbow.iloc[:, 1:]

# %%
exp = setup(data=training_cbow, target='label', train_size=0.8, )
# Out:
# <style type="text/css">
# #T_0d93e_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0d93e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d93e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d93e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0d93e_row0_col1" class="data row0 col1" >633</td>
#     </tr>
#     <tr>
#       <th id="T_0d93e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d93e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0d93e_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_0d93e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d93e_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_6c536_ th {
#   text-align: left;
# }
# ...
