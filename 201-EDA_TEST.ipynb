# %% [markdown]
# # 02- Exploratory Data Analysis (EDA)

# %%
import random
import pickle
from collections import Counter

import nltk

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

from gensim.models import Word2Vec

# %%
df = pd.read_pickle('../data/cleaned_tweets_test.pkl')

# %%
df.head()
# Out:
#                                                 text  label    category  \
# 0  we are living in scary times in canada. gov’t ...      0  unreliable
# 1  just as bad in canada. in fact, our government...      0  unreliable
# 2  it was only a matter of time before the mainst...      0  unreliable
# 3  russia's taking no chances: foreigners infecte...      0  unreliable
# 4  although there is now a presumptive confirmed ...      0  unreliable
#
#                                              cleaned  num_words
# 0  living scary time canada gov refuse protect ca...          9
# 1  bad canada fact government accusing us racism ...         10
# 2  matter time mainstream medium decided blame co...         10
# 3  russia taking chance foreigner infected new ch...         13
# 4  although presumptive confirmed case wuhan nove...         11

# %%
df.label.value_counts()
# Out:
# 0    280
# 1    277
# Name: label, dtype: int64

# %%
df.category.value_counts()
# Out:
# unreliable    280
# true          277
# Name: category, dtype: int64

# %% [markdown]
# #### distribution of number of words in a tweet per true / unreliable category

# %%
df.num_words.hist(by=df.category, figsize=(14,6), bins=20)
plt.show()

# %% [markdown]
# #### count of (non distinct) words in each category

# %%
bow_true = []
for word in df[df.category == 'true'].cleaned.str.split().to_list():
    bow_true += word

# %%
bow_unreliable = []
for word in df[df.category == 'unreliable'].cleaned.str.split().to_list():
    bow_unreliable += word

# %%
len(bow_true)
# Out:
# 2829

# %%
len(bow_unreliable)
# Out:
# 3295

# %% [markdown]
# #### most common words in each category

# %%
plt.figure(figsize=(14,6))
nltk.FreqDist(bow_true).plot(30,
                             title='Most common words in true category')
plt.show()

# %%
Counter(bow_true).most_common(100)
# Out:
# [('coronavirus', 221),
#  ('covid', 148),
#  ('case', 69),
#  ('new', 51),
#  ('health', 36),
#  ('ontario', 33),
#  ('outbreak', 25),
#  ('spread', 23),
#  ('confirmed', 21),
#  ('china', 21),
#  ('positive', 18),
#  ('toronto', 18),
#  ('novel', 17),
#  ('canada', 17),
#  ('say', 17),
#  ('death', 16),
#  ('first', 16),
#  ('update', 15),
#  ('official', 15),
#  ('emergency', 14),
#  ('travel', 13),
#  ('test', 13),
#  ('global', 13),
#  ('fear', 12),
#  ('people', 12),
#  ('state', 12),
#  ('misinformation', 11),
#  ('via', 11),
#  ('school', 11),
#  ('report', 11),
#  ('breaking', 11),
#  ('pandemic', 11),
#  ('us', 11),
#  ('news', 11),
#  ('time', 11),
#  ('public', 10),
#  ('march', 10),
#  ('york', 10),
#  ('declares', 10),
#  ('amid', 10),
#  ('due', 10),
#  ('canadian', 10),
#  ('virus', 9),
#  ('home', 9),
#  ('man', 9),
#  ('number', 9),
#  ('community', 8),
#  ('wuhan', 8),
#  ('infection', 8),
#  ('could', 8),
#  ('tested', 8),
#  ('stop', 8),
#  ('conference', 8),
#  ('system', 8),
#  ('patient', 7),
#  ('concern', 7),
#  ('italy', 7),
#  ('th', 7),
#  ('total', 7),
#  ('province', 7),
#  ('care', 7),
#  ('world', 7),
#  ('live', 7),
#  ('country', 6),
#  ('c', 6),
#  ('trump', 6),
#  ('response', 6),
#  ('get', 6),
#  ('government', 6),
#  ('korea', 6),
#  ('make', 6),
#  ('confirms', 6),
#  ('tokyo', 6),
#  ('trudeau', 6),
#  ('please', 6),
#  ('disease', 6),
#  ('need', 6),
#  ('one', 6),
#  ('spreading', 5),
#  ('week', 5),
#  ('chinese', 5),
#  ('announced', 5),
#  ('show', 5),
#  ('latest', 5),
#  ('quarantine', 5),
#  ('closed', 5),
#  ('bringing', 5),
#  ('iran', 5),
#  ('b', 5),
#  ('washington', 5),
#  ('hospital', 5),
#  ('expert', 5),
#  ('including', 5),
#  ('south', 5),
#  ('organization', 5),
#  ('olympics', 5),
#  ('transit', 5),
#  ('hit', 5),
#  ('employee', 5),
#  ('travelled', 5)]

# %%
plt.figure(figsize=(14,6))
nltk.FreqDist(bow_unreliable).plot(30,
                             title='Most common words in unreliable category')
plt.show()

# %%
Counter(bow_unreliable).most_common(100)
# Out:
# [('coronavirus', 272),
#  ('trump', 59),
#  ('people', 38),
#  ('china', 29),
#  ('us', 25),
#  ('news', 18),
#  ('lie', 17),
#  ('health', 16),
#  ('wuhan', 15),
#  ('covid', 15),
#  ('medium', 14),
#  ('case', 14),
#  ('market', 14),
#  ('american', 13),
#  ('spread', 13),
#  ('virus', 13),
#  ('could', 13),
#  ('chinese', 12),
#  ('say', 12),
#  ('go', 12),
#  ('flu', 12),
#  ('spreading', 12),
#  ('government', 11),
#  ('world', 11),
#  ('take', 11),
#  ('democrat', 11),
#  ('one', 11),
#  ('hoax', 11),
#  ('canada', 10),
#  ('infected', 10),
#  ('new', 10),
#  ('amp', 10),
#  ('iran', 10),
#  ('lying', 10),
#  ('stock', 10),
#  ('cdc', 10),
#  ('like', 9),
#  ('think', 9),
#  ('outbreak', 9),
#  ('video', 9),
#  ('president', 9),
#  ('get', 9),
#  ('everyone', 9),
#  ('fake', 9),
#  ('know', 8),
#  ('make', 8),
#  ('stop', 8),
#  ('trying', 8),
#  ('said', 8),
#  ('would', 8),
#  ('vaccine', 8),
#  ('real', 8),
#  ('public', 7),
#  ('man', 7),
#  ('see', 7),
#  ('kill', 7),
#  ('going', 7),
#  ('penny', 7),
#  ('pandemic', 7),
#  ('called', 7),
#  ('country', 7),
#  ('time', 6),
#  ('want', 6),
#  ('rt', 6),
#  ('economy', 6),
#  ('crisis', 6),
#  ('false', 6),
#  ('watch', 6),
#  ('help', 6),
#  ('please', 6),
#  ('super', 6),
#  ('donald', 6),
#  ('many', 6),
#  ('let', 6),
#  ('much', 6),
#  ('today', 6),
#  ('call', 6),
#  ('last', 6),
#  ('death', 6),
#  ('look', 6),
#  ('fear', 6),
#  ('refuse', 5),
#  ('canadian', 5),
#  ('fact', 5),
#  ('killed', 5),
#  ('well', 5),
#  ('used', 5),
#  ('something', 5),
#  ('maga', 5),
#  ('buy', 5),
#  ('medical', 5),
#  ('attempt', 5),
#  ('beer', 5),
#  ('america', 5),
#  ('conspiracy', 5),
#  ('theory', 5),
#  ('emergency', 5),
#  ('anyone', 5),
#  ('work', 5),
#  ('threat', 5)]

# %% [markdown]
# #### Word Cloud

# %%
wc_true = WordCloud().generate_from_frequencies(nltk.FreqDist(bow_true))
wc_unreliable = WordCloud().generate_from_frequencies(nltk.FreqDist(bow_unreliable))

# %%
plt.figure(figsize=(14,8))
plt.imshow(wc_true, interpolation='bilinear')
plt.title('true tweets word cloud')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.imshow(wc_unreliable, interpolation='bilinear')
plt.title('unreliable tweets word cloud')
plt.axis('off')
plt.show()

# %% [markdown]
# #### size of vocabulary (distinct words)

# %%
len(set(bow_true))
# Out:
# 1089

# %%
len(set(bow_unreliable))
# Out:
# 1583

# %%
words = bow_true + bow_unreliable

# %%
texts =  [(tweet, cat) for tweet, cat in zip(df.cleaned.to_list(), df.category.to_list())]

# %%
tweets, labels = (zip(*texts))

# %% [markdown]
# ## Word Embeddings

# %% [markdown]
# Create word embedding on all words of the test set

# %%
corpus = [tweet.split() for tweet in tweets]

# %%
model_cbow = Word2Vec(corpus, vector_size=300, window=3, min_count=0)
model_sg = Word2Vec(corpus, vector_size=300, window=3, min_count=0, sg=1)

# %%
testing_words = set(words)

# %%
we_cbow = {word: model_cbow.wv[word] for word in testing_words}
we_sg = {word: model_sg.wv[word] for word in testing_words}

# %%
training_words = pickle.load(open('../data/training_words_set.pickle', 'rb'))

# %%
def maxi_meaner(word_embedding, tweets, training_words):
    # excludes words that are not in the training words
    tweet_embedding = {}
    for i, tweet in enumerate(tweets):
        tweet_embedding[tweet] = np.mean(np.array([word_embedding[word] for word in tweets[i].split() if word in training_words]), axis=0)
    return tweet_embedding

# %%
te_cbow = maxi_meaner(we_cbow, tweets, training_words)
te_sg = maxi_meaner(we_sg, tweets, training_words)

# %%
len(te_cbow), len(te_sg)
# Out:
# (557, 557)

# %%
te_cbow_df = pd.DataFrame(te_cbow).T.reset_index().rename(columns={'index':'tweet'})
te_cbow_df['label'] = labels
te_sg_df = pd.DataFrame(te_sg).T.reset_index().rename(columns={'index':'tweet'})
te_sg_df['label'] = labels

# %%
te_cbow_df.head()
# Out:
#                                                tweet         0         1  \
# 0  living scary time canada gov refuse protect ca...  0.000222  0.000607
# 1  bad canada fact government accusing us racism ...  0.000761  0.001267
# 2  matter time mainstream medium decided blame co...  0.000936  0.000903
# 3  russia taking chance foreigner infected new ch... -0.000565  0.000807
# 4  although presumptive confirmed case wuhan nove...  0.000174  0.002205
#
#           2         3         4         5         6         7         8  ...  \
# 0 -0.000136  0.001046  0.000083 -0.001655  0.002308  0.002099 -0.000209  ...
# 1  0.000060  0.000959 -0.000113 -0.000897  0.001838  0.002432  0.001776  ...
# 2 -0.001037  0.001102 -0.000871 -0.000632  0.001927  0.002162 -0.000837  ...
# 3  0.000217  0.000854 -0.000411 -0.001540  0.001135  0.001972  0.000742  ...
# 4  0.000108 -0.000180 -0.000300 -0.002720  0.001286  0.002666 -0.000663  ...
#
#         291       292       293       294       295       296       297  \
# 0  0.002113  0.001142 -0.000281  0.001987  0.000781  0.000103 -0.000724
# 1  0.003117  0.001525  0.000967  0.002123  0.001578  0.001145  0.000153
# 2  0.002400  0.000737  0.000362  0.002636  0.001953  0.000255 -0.000690
# 3  0.002543  0.000653  0.000484  0.001073  0.001002  0.000829  0.000034
# 4  0.001983  0.001489 -0.000191  0.002877  0.001286 -0.000065 -0.000315
#
#         298       299       label
# 0  0.000719  0.000486  unreliable
# 1  0.000081 -0.000251  unreliable
# 2  0.001928  0.001618  unreliable
# 3  0.000310  0.000197  unreliable
# 4  0.001614 -0.001092  unreliable
#
# [5 rows x 302 columns]

# %%
pickle.dump(te_cbow_df, open("../data/te_cbow_df_testing.pickle", "wb"))
pickle.dump(te_sg_df, open("../data/te_sg_df_testing.pickle", "wb"))
